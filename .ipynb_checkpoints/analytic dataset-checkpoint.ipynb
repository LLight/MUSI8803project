# %%
from music21 import *
import pandas as pd
import os

# %%
csvFiles=[]
for f in os.listdir('./csv_files'):
    if f.find('.csv')>0:
        csvFiles.append(f)

# %%
csvFiles
# Out:
# ['AlariodelRio_Sol_Sostenido 3.csv',
#  'Albeniz_Suite_Espana_6_Zortzico_Op165_E_major.csv',
#  'Alkan_25_Preludes_Premiere_Suite_9_Placiditas_Tranquillement_in_E-_Op31_E_major.csv',
#  'Allard_5diversions.csv',
#  'Bachlund_Commedia_Dellarte.csv',
#  'Bargy_Pianoflage.csv',
#  'Bartok_Romanian_Folk_Dances_2_Braul.csv',
#  'Beatty_Musing_for_Piano.csv',
#  'Brahms_Rhapsody_79.csv',
#  'Burgmuller_Etude_Tendre_Fluer.csv',
#  'Carbajo_Yellow_Saraband.csv',
#  'Chopin Nocturne 55 1 F minor.csv',
#  'Copland_Piano_Blues_No_3.csv',
#  'Czerny Etudes Op299No9 C major.csv',
#  'DAragona_Studies_No7_F_major.csv',
#  'Debussy_Childrens_Corner.csv',
#  'Dvorak_Humoresque_in_B_Op101No2_B_major.csv',
#  'Haberbier_Studi-Poetici_Rimprovero_Op53No12_G#_Minor.csv',
#  'Hummel_Six_Bagatelles_IV_Rondo_Op107 .csv',
#  'Khachatruian_Album_for_Children_4_Cumpleanos.csv',
#  'Liszt La Cloche Sonne.csv',
#  'Liszt Lighting the Tree.csv',
#  'Mendelssohn Op 102 No1.csv',
#  'Messiaen_Regard_du_Pere.csv',
#  'Part_Fuer_Alina.csv',
#  'Poulenc_Les_chemins_de_lamour.csv',
#  'Rachmaninov_Prelude_in_C#-_Op3No2.csv',
#  'Rautavaara_Etude_op42_no1_Thirds.csv',
#  'Saint Saens 6 Etudes for Piano Op 111 Prelude and Fugue Eb minor.csv',
#  'Satie_Ogives_No3 .csv',
#  'Schnittke_Tango.csv',
#  'Schubert Con Moto D850 II A Major.csv',
#  'Schumann Waldszenen Op 82 Verrufene Stelle.csv',
#  'Scriabin_Seven_Preludes_Op17No5 .csv',
#  'Sculthorpe_Sea_Chant.csv',
#  'Shostakovich_Aphorisms 8_Canon_Op13No8.csv',
#  'Simpson_Invention_no6.csv',
#  'Stravinsky_Les_Cinq_Doigts_Larghetto.csv',
#  'Takemitsu_Romance.csv',
#  'Zhang_Mazurka.csv']

# %%
i=0
while (i<len(csvFiles)):
    #print(i)
    #print(csvFiles[i])
    df_piece=pd.read_csv('csv_files/'+csvFiles[i])
    if i==0:
        df=df_piece
    else:
        df=pd.concat([df,df_piece],axis=0,sort=True)
    i+=1

# %%
df
# Out:
#                                                   Chord      Composer  \
# 0                              <music21.chord.Chord E3>  AlariodelRio
# 1                             <music21.chord.Chord A#3>  AlariodelRio
# 2                             <music21.chord.Chord G#3>  AlariodelRio
# 3                             <music21.chord.Chord D#3>  AlariodelRio
# 4                             <music21.chord.Chord A#3>  AlariodelRio
# ...                                                 ...           ...
# 1117                          <music21.chord.Chord A-2>         Zhang
# 1118                          <music21.chord.Chord D-2>         Zhang
# 1119  <music21.chord.Chord G-1 G-2 A2 C#3 E3 B--3 D-...         Zhang
# 1120            <music21.chord.Chord D-1 D-2 F4 A-4 F5>         Zhang
# 1121  <music21.chord.Chord G2 A2 C#3 E3 A-3 B-3 D-4 ...         Zhang
#
#                                 File  Measure Beat  Measure Beat Number  \
# 0     AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 1     AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 2     AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 3     AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 4     AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# ...                              ...           ...                  ...
# 1117               Zhang_Mazurka.xml           NaN                  NaN
# 1118               Zhang_Mazurka.xml           NaN                  NaN
# 1119               Zhang_Mazurka.xml           NaN                  NaN
# 1120               Zhang_Mazurka.xml           NaN                  NaN
# 1121               Zhang_Mazurka.xml           NaN                  NaN
#
#       Measure Beat Number.1 Measure Count  MeasureCount  \
# 0                       NaN             1           NaN
# 1                       NaN         1 1/4           NaN
# 2                       NaN         1 1/2           NaN
# 3                       NaN         1 3/4           NaN
# 4                       NaN             2           NaN
# ...                     ...           ...           ...
# 1117                    NaN           NaN           NaN
# 1118                    NaN           NaN           NaN
# 1119                    NaN           NaN           NaN
# 1120                    NaN           NaN           NaN
# 1121                    NaN           NaN           NaN
#
#                  NormalForm   Offset         PCsInNormalForm beatNumber  \
# 0                       [0]    0.000                     [4]        NaN
# 1                       [0]    0.500                    [10]        NaN
# 2                       [0]    1.000                     [8]        NaN
# 3                       [0]    1.500                     [3]        NaN
# 4                       [0]    2.000                    [10]        NaN
# ...                     ...      ...                     ...        ...
# 1117                    [0]  365.875                     [8]      4 7/8
# 1118                    [0]  366.000                     [1]          1
# 1119           [0, 3, 5, 8]  368.000            [1, 4, 6, 9]          3
# 1120              [0, 4, 7]  370.000               [1, 5, 8]          1
# 1121  [0, 3, 4, 6, 7, 8, 9]  372.000  [1, 4, 5, 7, 8, 9, 10]          3
#
#       measureNumber
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1117          109.0
# 1118          110.0
# 1119          110.0
# 1120          111.0
# 1121          111.0
#
# [31017 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Chord', 'Composer', 'File', 'Measure Beat', 'Measure Beat Number',
#        'Measure Beat Number.1', 'Measure Count', 'MeasureCount', 'NormalForm',
#        'Offset', 'PCsInNormalForm', 'beatNumber', 'measureNumber'],
#       dtype='object')

# %%
workList=pd.read_csv('workList.csv')

# %%
workList.columns
# Out:
# Index(['Unnamed: 0', 'pieceName', 'movementName', 'genre', 'Composer',
#        'publicationYear', 'Epoch', 'Source', 'fileFormat', 'phraseAnalysis',
#        'fileConversion', 'getChords'],
#       dtype='object')

# %%
df_pieceInfo=pd.merge(df,workList,how='outer',on='Composer')

# %%
df_pieceInfo.columns
# Out:
# Index(['Chord', 'Composer', 'File', 'Measure Beat', 'Measure Beat Number',
#        'Measure Beat Number.1', 'Measure Count', 'MeasureCount', 'NormalForm',
#        'Offset', 'PCsInNormalForm', 'beatNumber', 'measureNumber',
#        'Unnamed: 0', 'pieceName', 'movementName', 'genre', 'publicationYear',
#        'Epoch', 'Source', 'fileFormat', 'phraseAnalysis', 'fileConversion',
#        'getChords'],
#       dtype='object')

# %%
df_pieceInfo
# Out:
#                                                    Chord      Composer  \
# 0                               <music21.chord.Chord E3>  AlariodelRio
# 1                              <music21.chord.Chord A#3>  AlariodelRio
# 2                              <music21.chord.Chord G#3>  AlariodelRio
# 3                              <music21.chord.Chord D#3>  AlariodelRio
# 4                              <music21.chord.Chord A#3>  AlariodelRio
# ...                                                  ...           ...
# 31811                          <music21.chord.Chord A-2>         Zhang
# 31812                          <music21.chord.Chord D-2>         Zhang
# 31813  <music21.chord.Chord G-1 G-2 A2 C#3 E3 B--3 D-...         Zhang
# 31814            <music21.chord.Chord D-1 D-2 F4 A-4 F5>         Zhang
# 31815  <music21.chord.Chord G2 A2 C#3 E3 A-3 B-3 D-4 ...         Zhang
#
#                                  File  Measure Beat  Measure Beat Number  \
# 0      AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 1      AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 2      AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 3      AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# 4      AlariodelRio_Sol_Sostenido.xml           NaN                  NaN
# ...                               ...           ...                  ...
# 31811               Zhang_Mazurka.xml           NaN                  NaN
# 31812               Zhang_Mazurka.xml           NaN                  NaN
# 31813               Zhang_Mazurka.xml           NaN                  NaN
# 31814               Zhang_Mazurka.xml           NaN                  NaN
# 31815               Zhang_Mazurka.xml           NaN                  NaN
#
#        Measure Beat Number.1 Measure Count  MeasureCount  \
# 0                        NaN             1           NaN
# 1                        NaN         1 1/4           NaN
# 2                        NaN         1 1/2           NaN
# 3                        NaN         1 3/4           NaN
# 4                        NaN             2           NaN
# ...                      ...           ...           ...
# 31811                    NaN           NaN           NaN
# 31812                    NaN           NaN           NaN
# 31813                    NaN           NaN           NaN
# 31814                    NaN           NaN           NaN
# 31815                    NaN           NaN           NaN
#
#                   NormalForm   Offset  ...        pieceName  \
# 0                        [0]    0.000  ...  Piano Piece No8
# 1                        [0]    0.500  ...  Piano Piece No8
# 2                        [0]    1.000  ...  Piano Piece No8
# 3                        [0]    1.500  ...  Piano Piece No8
# 4                        [0]    2.000  ...  Piano Piece No8
# ...                      ...      ...  ...              ...
# 31811                    [0]  365.875  ...        24 Etudes
# 31812                    [0]  366.000  ...        24 Etudes
# 31813           [0, 3, 5, 8]  368.000  ...        24 Etudes
# 31814              [0, 4, 7]  370.000  ...        24 Etudes
# 31815  [0, 3, 4, 6, 7, 8, 9]  372.000  ...        24 Etudes
#
#                          movementName      genre publicationYear      Epoch  \
# 0                             Op7 No2  OtherSolo            2013  1970-2020
# 1                             Op7 No2  OtherSolo            2013  1970-2020
# 2                             Op7 No2  OtherSolo            2013  1970-2020
# 3                             Op7 No2  OtherSolo            2013  1970-2020
# 4                             Op7 No2  OtherSolo            2013  1970-2020
# ...                               ...        ...             ...        ...
# 31811  No15 Mazurka with Chinese Trio      Etude            2015  1970-2020
# 31812  No15 Mazurka with Chinese Trio      Etude            2015  1970-2020
# 31813  No15 Mazurka with Chinese Trio      Etude            2015  1970-2020
# 31814  No15 Mazurka with Chinese Trio      Etude            2015  1970-2020
# 31815  No15 Mazurka with Chinese Trio      Etude            2015  1970-2020
#
#       Source fileFormat  phraseAnalysis fileConversion getChords
# 0      IMSLP        PDF               N              Y         Y
# 1      IMSLP        PDF               N              Y         Y
# 2      IMSLP        PDF               N              Y         Y
# 3      IMSLP        PDF               N              Y         Y
# 4      IMSLP        PDF               N              Y         Y
# ...      ...        ...             ...            ...       ...
# 31811  IMSLP        PDF               N              Y         Y
# 31812  IMSLP        PDF               N              Y         Y
# 31813  IMSLP        PDF               N              Y         Y
# 31814  IMSLP        PDF               N              Y         Y
# 31815  IMSLP        PDF               N              Y         Y
#
# [31816 rows x 24 columns]

# %%
df_pieceInfo['Composer'].value_counts()
# Out:
# Beatty          3409
# Brahms          2868
# Bargy           1942
# Hummel          1680
# Schubert        1673
# Liszt           1598
# Rautavaara      1577
# Saint-Saens     1332
# Rachmaninov     1285
# Czerny          1155
# Zhang           1122
# Chopin          1055
# Simpson          966
# Scriabin         840
# Albeniz          783
# Debussy          738
# Khachatruian     659
# AlariodelRio     613
# Alkan            552
# Mendelssohn      514
# Schumann         504
# Allard           479
# Haberbier        457
# Messiaen         453
# Dvorak           452
# Burgmuller       422
# DAragona         420
# Carbajo          337
# Takemitsu        272
# Schnittke        252
# Poulenc          249
# Copland          228
# Bachlund         180
# Sculthorpe       164
# Bartok           151
# Stravinsky       146
# Shostakovich     143
# Satie             80
# Part              66
# Name: Composer, dtype: int64

# %%
df_pieceInfo.to_csv('analyticDataset.csv')
