# %%
from music21 import *
import pandas as pd

# %%
analyticDataset=pd.read_csv('analyticDataset.csv')

# %%
analyticDataset
# Out:
#        Unnamed: 0                                              Chord  \
# 0               0                           <music21.chord.Chord E3>
# 1               1                          <music21.chord.Chord A#3>
# 2               2                          <music21.chord.Chord G#3>
# 3               3                          <music21.chord.Chord D#3>
# 4               4                          <music21.chord.Chord A#3>
# ...           ...                                                ...
# 31150       31150                          <music21.chord.Chord A-2>
# 31151       31151                          <music21.chord.Chord D-2>
# 31152       31152  <music21.chord.Chord G-1 G-2 A2 C#3 E3 B--3 D-...
# 31153       31153            <music21.chord.Chord D-1 D-2 F4 A-4 F5>
# 31154       31154  <music21.chord.Chord G2 A2 C#3 E3 A-3 B-3 D-4 ...
#
#            Composer                            File  Measure Beat  \
# 0      AlariodelRio  AlariodelRio_Sol_Sostenido.xml           NaN
# ...

# %%
analyticDataset['NormalForm'].value_counts()
# Out:
# [0]                          8142
# [0, 5]                       2696
# [0, 4]                       2596
# [0, 4, 7]                    2526
# [0, 3]                       2491
#                              ...
# [0, 1, 3, 4, 5, 8]              1
# [0, 2, 4, 6, 8, 9]              1
# [0, 2, 3, 5, 6, 8, 9, 10]       1
# [0, 3, 4, 6, 7, 8, 9]           1
# [0, 3, 4, 5, 7]                 1
# Name: NormalForm, Length: 154, dtype: int64

# %%
analyticDataset['Chord'].value_counts()
# Out:
# <music21.chord.Chord A4>                243
# <music21.chord.Chord C5>                241
# <music21.chord.Chord G4>                212
# <music21.chord.Chord D4>                210
# <music21.chord.Chord D5>                198
#                                        ...
# <music21.chord.Chord B-4 F4 C#2>          1
# <music21.chord.Chord D-2 F4 E--5>         1
# <music21.chord.Chord C4 C6 C5>            1
# <music21.chord.Chord E-5 G5 E-4 E-3>      1
# <music21.chord.Chord G3 B3 G2>            1
# Name: Chord, Length: 10989, dtype: int64
